# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 725

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
       # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ambon
# Processing Record 2 of Set 1 | komsomolskiy
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | cheremukhovo
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | agva
# City not found. Skipping...
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | bowen
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | tual
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | portland
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | yei
# Processing Record 21 of Set 1 | wanning
# Processing Record 22 of Set 1 | kaitong
# Processing Record 23 of Set 1 | aksu
# Processing Record 24 of Set 1 | kahului
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | faanui
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | riachao
# Processing Record 29 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | kieta
# Processing Record 32 of Set 1 | phalaborwa
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | hofn
# Processing Record 35 of Set 1 | zheleznodorozhnyy
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | narsaq
# Processing Record 38 of Set 1 | pangnirtung
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | kanel
# Processing Record 41 of Set 1 | kjollefjord
# Processing Record 42 of Set 1 | constitucion
# Processing Record 43 of Set 1 | aklavik
# Processing Record 44 of Set 1 | port lincoln
# Processing Record 45 of Set 1 | camapua
# Processing Record 46 of Set 1 | pingliang
# Processing Record 47 of Set 1 | esperance
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | yulara
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | longyearbyen
# Processing Record 7 of Set 2 | port augusta
# Processing Record 8 of Set 2 | khor
# Processing Record 9 of Set 2 | gotsu
# Processing Record 10 of Set 2 | thinadhoo
# Processing Record 11 of Set 2 | mikkeli
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 2 | progreso
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | hay river
# Processing Record 17 of Set 2 | hukuntsi
# Processing Record 18 of Set 2 | port blair
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | albany
# Processing Record 24 of Set 2 | zalantun
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 2 | bizhbulyak
# Processing Record 28 of Set 2 | turukhansk
# Processing Record 29 of Set 2 | suez
# Processing Record 30 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 2 | taltal
# Processing Record 32 of Set 2 | tautira
# Processing Record 33 of Set 2 | champerico
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | lucapa
# Processing Record 36 of Set 2 | porto novo
# Processing Record 37 of Set 2 | huarmey
# Processing Record 38 of Set 2 | talnakh
# Processing Record 39 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 2 | okha
# Processing Record 41 of Set 2 | atuona
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | edmond
# Processing Record 44 of Set 2 | sokoni
# Processing Record 45 of Set 2 | geraldton
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | sisimiut
# Processing Record 48 of Set 2 | ust-kulom
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | bonawon
# Processing Record 1 of Set 3 | kavieng
# Processing Record 2 of Set 3 | sitka
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 3 | sijunjung
# Processing Record 5 of Set 3 | clyde river
# Processing Record 6 of Set 3 | ahipara
# Processing Record 7 of Set 3 | cape town
# Processing Record 8 of Set 3 | puri
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | kununurra
# Processing Record 11 of Set 3 | leshukonskoye
# Processing Record 12 of Set 3 | katsuura
# Processing Record 13 of Set 3 | coahuayana
# Processing Record 14 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 15 of Set 3 | opuwo
# Processing Record 16 of Set 3 | reynoldsburg
# Processing Record 17 of Set 3 | severo-kurilsk
# Processing Record 18 of Set 3 | joao pinheiro
# Processing Record 19 of Set 3 | dunedin
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | kaduy
# Processing Record 22 of Set 3 | kiama
# Processing Record 23 of Set 3 | guerrero negro
# Processing Record 24 of Set 3 | west wendover
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 3 | lorengau
# Processing Record 28 of Set 3 | iqaluit
# Processing Record 29 of Set 3 | dudinka
# Processing Record 30 of Set 3 | rawson
# Processing Record 31 of Set 3 | flin flon
# Processing Record 32 of Set 3 | chifeng
# Processing Record 33 of Set 3 | katobu
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | lar gerd
# City not found. Skipping...
# Processing Record 36 of Set 3 | yerbogachen
# Processing Record 37 of Set 3 | olafsvik
# Processing Record 38 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 3 | lagoa
# Processing Record 40 of Set 3 | gat
# Processing Record 41 of Set 3 | arlit
# Processing Record 42 of Set 3 | upernavik
# Processing Record 43 of Set 3 | tilichiki
# Processing Record 44 of Set 3 | springbok
# Processing Record 45 of Set 3 | selenginsk
# Processing Record 46 of Set 3 | ningyang
# Processing Record 47 of Set 3 | luderitz
# Processing Record 48 of Set 3 | troitsko-pechorsk
# Processing Record 49 of Set 3 | naze
# Processing Record 50 of Set 3 | codrington
# Processing Record 1 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 4 | nouadhibou
# Processing Record 3 of Set 4 | lalmohan
# Processing Record 4 of Set 4 | kilis
# Processing Record 5 of Set 4 | ongandjera
# Processing Record 6 of Set 4 | qaanaaq
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | umm jarr
# City not found. Skipping...
# Processing Record 9 of Set 4 | shimoda
# Processing Record 10 of Set 4 | bhitarwar
# Processing Record 11 of Set 4 | nanchital
# Processing Record 12 of Set 4 | tarko-sale
# Processing Record 13 of Set 4 | semnan
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | alofi
# Processing Record 16 of Set 4 | ilulissat
# Processing Record 17 of Set 4 | los llanos de aridane
# Processing Record 18 of Set 4 | vilhena
# Processing Record 19 of Set 4 | shingu
# Processing Record 20 of Set 4 | camocim
# Processing Record 21 of Set 4 | terney
# Processing Record 22 of Set 4 | udayagiri
# Processing Record 23 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | manzanillo
# Processing Record 26 of Set 4 | monywa
# Processing Record 27 of Set 4 | ullapool
# Processing Record 28 of Set 4 | kenai
# Processing Record 29 of Set 4 | havoysund
# Processing Record 30 of Set 4 | new norfolk
# Processing Record 31 of Set 4 | srandakan
# Processing Record 32 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 4 | sterling
# Processing Record 34 of Set 4 | ayr
# Processing Record 35 of Set 4 | souillac
# Processing Record 36 of Set 4 | prince rupert
# Processing Record 37 of Set 4 | chotila
# Processing Record 38 of Set 4 | sao filipe
# Processing Record 39 of Set 4 | sandovo
# Processing Record 40 of Set 4 | pevek
# Processing Record 41 of Set 4 | cayenne
# Processing Record 42 of Set 4 | chuy
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | xiamen
# Processing Record 45 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 4 | laguna
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | noumea
# Processing Record 49 of Set 4 | havre
# Processing Record 50 of Set 4 | mangrol
# Processing Record 1 of Set 5 | araouane
# Processing Record 2 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 3 of Set 5 | necochea
# Processing Record 4 of Set 5 | hirara
# Processing Record 5 of Set 5 | tayoltita
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | sarakhs
# Processing Record 8 of Set 5 | weihe
# Processing Record 9 of Set 5 | abu dhabi
# Processing Record 10 of Set 5 | tiksi
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 5 | solikamsk
# Processing Record 14 of Set 5 | lexington-fayette
# Processing Record 15 of Set 5 | tarakan
# Processing Record 16 of Set 5 | buenos aires
# Processing Record 17 of Set 5 | namibe
# Processing Record 18 of Set 5 | high prairie
# Processing Record 19 of Set 5 | krasnoarmeysk
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | daru
# Processing Record 22 of Set 5 | meulaboh
# Processing Record 23 of Set 5 | aswan
# Processing Record 24 of Set 5 | aras
# Processing Record 25 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 5 | yar-sale
# Processing Record 27 of Set 5 | santa maria
# Processing Record 28 of Set 5 | grindavik
# Processing Record 29 of Set 5 | nome
# Processing Record 30 of Set 5 | seoul
# Processing Record 31 of Set 5 | arraial do cabo
# Processing Record 32 of Set 5 | dickinson
# Processing Record 33 of Set 5 | rusera
# Processing Record 34 of Set 5 | tiznit
# Processing Record 35 of Set 5 | estevan
# Processing Record 36 of Set 5 | cardston
# Processing Record 37 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 5 | thompson
# Processing Record 39 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 40 of Set 5 | byron bay
# Processing Record 41 of Set 5 | saint-georges
# Processing Record 42 of Set 5 | nanortalik
# Processing Record 43 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 5 | pleszew
# Processing Record 45 of Set 5 | alenquer
# Processing Record 46 of Set 5 | marysville
# Processing Record 47 of Set 5 | salalah
# Processing Record 48 of Set 5 | rio gallegos
# Processing Record 49 of Set 5 | isoka
# Processing Record 50 of Set 5 | kodiak
# Processing Record 1 of Set 6 | vao
# Processing Record 2 of Set 6 | valparaiso
# Processing Record 3 of Set 6 | tarn taran
# Processing Record 4 of Set 6 | mahebourg
# Processing Record 5 of Set 6 | mount gambier
# Processing Record 6 of Set 6 | san patricio
# Processing Record 7 of Set 6 | isangel
# Processing Record 8 of Set 6 | wenling
# Processing Record 9 of Set 6 | saint-joseph
# Processing Record 10 of Set 6 | carnarvon
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | faya
# Processing Record 13 of Set 6 | jalingo
# Processing Record 14 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 6 | udachnyy
# Processing Record 16 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 17 of Set 6 | salinas
# Processing Record 18 of Set 6 | hilo
# Processing Record 19 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 6 | lavrentiya
# Processing Record 21 of Set 6 | svetlyy
# Processing Record 22 of Set 6 | torbay
# Processing Record 23 of Set 6 | ballina
# Processing Record 24 of Set 6 | richmond
# Processing Record 25 of Set 6 | songkhla
# Processing Record 26 of Set 6 | luganville
# Processing Record 27 of Set 6 | la uribe
# City not found. Skipping...
# Processing Record 28 of Set 6 | cap malheureux
# Processing Record 29 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 6 | tornio
# Processing Record 31 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 6 | barcelos
# Processing Record 33 of Set 6 | mananara
# Processing Record 34 of Set 6 | lompoc
# Processing Record 35 of Set 6 | cururupu
# Processing Record 36 of Set 6 | hami
# Processing Record 37 of Set 6 | natulongan
# City not found. Skipping...
# Processing Record 38 of Set 6 | payo
# Processing Record 39 of Set 6 | morondava
# Processing Record 40 of Set 6 | novyy urengoy
# Processing Record 41 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 6 | saldanha
# Processing Record 43 of Set 6 | ligayan
# Processing Record 44 of Set 6 | frontera
# Processing Record 45 of Set 6 | solnechnyy
# Processing Record 46 of Set 6 | puro
# Processing Record 47 of Set 6 | great falls
# Processing Record 48 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 6 | makakilo city
# Processing Record 50 of Set 6 | gua musang
# Processing Record 1 of Set 7 | stromness
# Processing Record 2 of Set 7 | arman
# Processing Record 3 of Set 7 | grand island
# Processing Record 4 of Set 7 | evensk
# Processing Record 5 of Set 7 | san policarpo
# Processing Record 6 of Set 7 | hibbing
# Processing Record 7 of Set 7 | norman wells
# Processing Record 8 of Set 7 | bolshaya atnya
# City not found. Skipping...
# Processing Record 9 of Set 7 | norwich
# Processing Record 10 of Set 7 | sokolniki
# Processing Record 11 of Set 7 | matay
# Processing Record 12 of Set 7 | ostrovnoy
# Processing Record 13 of Set 7 | hearst
# Processing Record 14 of Set 7 | krasnoselkup
# Processing Record 15 of Set 7 | hambantota
# Processing Record 16 of Set 7 | urumqi
# Processing Record 17 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 7 | moiyabana
# City not found. Skipping...
# Processing Record 19 of Set 7 | charyshskoye
# Processing Record 20 of Set 7 | bundaberg
# Processing Record 21 of Set 7 | carballo
# Processing Record 22 of Set 7 | rudbar
# Processing Record 23 of Set 7 | kassala
# Processing Record 24 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 25 of Set 7 | ust-kuyga
# Processing Record 26 of Set 7 | ajdabiya
# Processing Record 27 of Set 7 | neiafu
# Processing Record 28 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 29 of Set 7 | berlevag
# Processing Record 30 of Set 7 | nikolskoye
# Processing Record 31 of Set 7 | aberdeen
# Processing Record 32 of Set 7 | cabo san lucas
# Processing Record 33 of Set 7 | saurimo
# Processing Record 34 of Set 7 | muros
# Processing Record 35 of Set 7 | castro
# Processing Record 36 of Set 7 | pochutla
# Processing Record 37 of Set 7 | astana
# Processing Record 38 of Set 7 | batagay
# Processing Record 39 of Set 7 | bonavista
# Processing Record 40 of Set 7 | ugoofaaru
# Processing Record 41 of Set 7 | amapa
# Processing Record 42 of Set 7 | madang
# Processing Record 43 of Set 7 | pangai
# Processing Record 44 of Set 7 | fortuna
# Processing Record 45 of Set 7 | kailua
# Processing Record 46 of Set 7 | kudahuvadhoo
# Processing Record 47 of Set 7 | ust-dzheguta
# Processing Record 48 of Set 7 | port moresby
# Processing Record 49 of Set 7 | kokopo
# Processing Record 50 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 1 of Set 8 | cockburn town
# Processing Record 2 of Set 8 | airai
# Processing Record 3 of Set 8 | vanimo
# Processing Record 4 of Set 8 | coihaique
# Processing Record 5 of Set 8 | dondo
# Processing Record 6 of Set 8 | lincoln
# Processing Record 7 of Set 8 | tateyama
# Processing Record 8 of Set 8 | huallanca
# Processing Record 9 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 8 | burnie
# Processing Record 11 of Set 8 | nioro
# Processing Record 12 of Set 8 | fort dix
# Processing Record 13 of Set 8 | sioux lookout
# Processing Record 14 of Set 8 | xining
# Processing Record 15 of Set 8 | acajutla
# Processing Record 16 of Set 8 | venado tuerto
# Processing Record 17 of Set 8 | freeport
# Processing Record 18 of Set 8 | mokhsogollokh
# Processing Record 19 of Set 8 | micheweni
# Processing Record 20 of Set 8 | ailigandi
# Processing Record 21 of Set 8 | taguatinga
# Processing Record 22 of Set 8 | sidi ali
# Processing Record 23 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 8 | ancud
# Processing Record 25 of Set 8 | komsomolskoye
# Processing Record 26 of Set 8 | inverell
# Processing Record 27 of Set 8 | praia
# Processing Record 28 of Set 8 | san jeronimito
# Processing Record 29 of Set 8 | nezhinka
# Processing Record 30 of Set 8 | luebo
# Processing Record 31 of Set 8 | havelock
# Processing Record 32 of Set 8 | pavino
# Processing Record 33 of Set 8 | samarai
# Processing Record 34 of Set 8 | xiuyan
# Processing Record 35 of Set 8 | usinsk
# Processing Record 36 of Set 8 | quelimane
# Processing Record 37 of Set 8 | paciran
# Processing Record 38 of Set 8 | phan thiet
# Processing Record 39 of Set 8 | padang
# Processing Record 40 of Set 8 | emerald
# Processing Record 41 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 42 of Set 8 | eldorado
# Processing Record 43 of Set 8 | manavalakurichi
# Processing Record 44 of Set 8 | stamsund
# City not found. Skipping...
# Processing Record 45 of Set 8 | moisakula
# Processing Record 46 of Set 8 | caravelas
# Processing Record 47 of Set 8 | klaksvik
# Processing Record 48 of Set 8 | kuala terengganu
# Processing Record 49 of Set 8 | kaeo
# Processing Record 50 of Set 8 | pemba
# Processing Record 1 of Set 9 | morro bay
# Processing Record 2 of Set 9 | diffa
# Processing Record 3 of Set 9 | camopi
# Processing Record 4 of Set 9 | axim
# Processing Record 5 of Set 9 | kavali
# Processing Record 6 of Set 9 | gornopravdinsk
# Processing Record 7 of Set 9 | orlik
# Processing Record 8 of Set 9 | brigg
# Processing Record 9 of Set 9 | leninskoye
# Processing Record 10 of Set 9 | galatini
# Processing Record 11 of Set 9 | olavarria
# Processing Record 12 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 9 | newport
# Processing Record 14 of Set 9 | bundi
# Processing Record 15 of Set 9 | chara
# Processing Record 16 of Set 9 | kopervik
# Processing Record 17 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 18 of Set 9 | coquimbo
# Processing Record 19 of Set 9 | bonanza
# Processing Record 20 of Set 9 | warren
# Processing Record 21 of Set 9 | tazovskiy
# Processing Record 22 of Set 9 | dawlatabad
# Processing Record 23 of Set 9 | sukumo
# Processing Record 24 of Set 9 | sapao
# City not found. Skipping...
# Processing Record 25 of Set 9 | hobyo
# Processing Record 26 of Set 9 | bambous virieux
# Processing Record 27 of Set 9 | college
# Processing Record 28 of Set 9 | uray
# Processing Record 29 of Set 9 | pingdu
# Processing Record 30 of Set 9 | moissac
# Processing Record 31 of Set 9 | vila velha
# Processing Record 32 of Set 9 | road town
# Processing Record 33 of Set 9 | tsagan aman
# Processing Record 34 of Set 9 | manggar
# Processing Record 35 of Set 9 | ocampo
# Processing Record 36 of Set 9 | varberg
# Processing Record 37 of Set 9 | benemerito de las americas
# Processing Record 38 of Set 9 | uige
# Processing Record 39 of Set 9 | calama
# Processing Record 40 of Set 9 | kulhudhuffushi
# Processing Record 41 of Set 9 | deogarh
# Processing Record 42 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 43 of Set 9 | chapais
# Processing Record 44 of Set 9 | baturaja
# Processing Record 45 of Set 9 | kunya
# Processing Record 46 of Set 9 | pizarro
# Processing Record 47 of Set 9 | gonzalez
# Processing Record 48 of Set 9 | stornoway
# Processing Record 49 of Set 9 | vatne
# Processing Record 50 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 10 | avera
# Processing Record 2 of Set 10 | dongsheng
# Processing Record 3 of Set 10 | pundaguitan
# Processing Record 4 of Set 10 | impfondo
# Processing Record 5 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 10 | port-gentil
# Processing Record 7 of Set 10 | asfi
# Processing Record 8 of Set 10 | staryy nadym
# Processing Record 9 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 10 | novaya usman
# Processing Record 11 of Set 10 | kloulklubed
# Processing Record 12 of Set 10 | spring hill
# Processing Record 13 of Set 10 | silver city
# Processing Record 14 of Set 10 | puerto colombia
# Processing Record 15 of Set 10 | charters towers
# Processing Record 16 of Set 10 | namtsy
# Processing Record 17 of Set 10 | teguldet
# Processing Record 18 of Set 10 | manokwari
# Processing Record 19 of Set 10 | burica
# City not found. Skipping...
# Processing Record 20 of Set 10 | mahajanga
# Processing Record 21 of Set 10 | gananoque
# Processing Record 22 of Set 10 | tigil
# Processing Record 23 of Set 10 | miracema do tocantins
# Processing Record 24 of Set 10 | jacareacanga
# Processing Record 25 of Set 10 | mitsamiouli
# Processing Record 26 of Set 10 | baykit
# Processing Record 27 of Set 10 | waingapu
# Processing Record 28 of Set 10 | nemuro
# Processing Record 29 of Set 10 | harper
# Processing Record 30 of Set 10 | lonavale
# Processing Record 31 of Set 10 | auki
# Processing Record 32 of Set 10 | turayf
# Processing Record 33 of Set 10 | north bend
# Processing Record 34 of Set 10 | mount isa
# Processing Record 35 of Set 10 | kroya
# Processing Record 36 of Set 10 | salisbury
# Processing Record 37 of Set 10 | itaituba
# Processing Record 38 of Set 10 | inhambane
# Processing Record 39 of Set 10 | madinat sittah uktubar
# Processing Record 40 of Set 10 | vaovai
# City not found. Skipping...
# Processing Record 41 of Set 10 | moerai
# Processing Record 42 of Set 10 | grand gaube
# Processing Record 43 of Set 10 | qandahar
# City not found. Skipping...
# Processing Record 44 of Set 10 | maniitsoq
# Processing Record 45 of Set 10 | karratha
# Processing Record 46 of Set 10 | la ronge
# Processing Record 47 of Set 10 | te anau
# Processing Record 48 of Set 10 | jega
# Processing Record 49 of Set 10 | brae
# Processing Record 50 of Set 10 | sosnovo
# Processing Record 1 of Set 11 | santa fe
# Processing Record 2 of Set 11 | natitingou
# Processing Record 3 of Set 11 | bulgan
# Processing Record 4 of Set 11 | zhigansk
# Processing Record 5 of Set 11 | rio grande
# Processing Record 6 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 11 | carutapera
# Processing Record 8 of Set 11 | vanavara
# Processing Record 9 of Set 11 | soto la marina
# Processing Record 10 of Set 11 | thaton
# Processing Record 11 of Set 11 | sola
# Processing Record 12 of Set 11 | hastings
# Processing Record 13 of Set 11 | nago
# Processing Record 14 of Set 11 | mlandizi
# Processing Record 15 of Set 11 | la union
# Processing Record 16 of Set 11 | nanded
# City not found. Skipping...
# Processing Record 17 of Set 11 | bac lieu
# Processing Record 18 of Set 11 | puerto del rosario
# Processing Record 19 of Set 11 | puntarenas
# Processing Record 20 of Set 11 | oranjemund
# Processing Record 21 of Set 11 | zhiryatino
# Processing Record 22 of Set 11 | atemar
# Processing Record 23 of Set 11 | vardo
# Processing Record 24 of Set 11 | shubarkuduk
# Processing Record 25 of Set 11 | kaitangata
# Processing Record 26 of Set 11 | oshikango
# Processing Record 27 of Set 11 | posse
# Processing Record 28 of Set 11 | lusambo
# Processing Record 29 of Set 11 | petrivka
# Processing Record 30 of Set 11 | rodrigues alves
# Processing Record 31 of Set 11 | berdigestyakh
# Processing Record 32 of Set 11 | belaya gora
# Processing Record 33 of Set 11 | mizusawa
# Processing Record 34 of Set 11 | boa vista
# Processing Record 35 of Set 11 | kaka
# Processing Record 36 of Set 11 | barreiras
# Processing Record 37 of Set 11 | quchan
# Processing Record 38 of Set 11 | sao felix do xingu
# Processing Record 39 of Set 11 | chake chake
# Processing Record 40 of Set 11 | fallon
# Processing Record 41 of Set 11 | mogok
# Processing Record 42 of Set 11 | tuatapere
# Processing Record 43 of Set 11 | liniere
# City not found. Skipping...
# Processing Record 44 of Set 11 | sept-iles
# Processing Record 45 of Set 11 | shakawe
# Processing Record 46 of Set 11 | launceston
# Processing Record 47 of Set 11 | banda aceh
# Processing Record 48 of Set 11 | mackay
# Processing Record 49 of Set 11 | ornskoldsvik
# Processing Record 50 of Set 11 | sembe
# Processing Record 1 of Set 12 | andenes
# Processing Record 2 of Set 12 | batemans bay
# Processing Record 3 of Set 12 | ifo
# Processing Record 4 of Set 12 | dicabisagan
# Processing Record 5 of Set 12 | tessalit
# Processing Record 6 of Set 12 | acarau
# Processing Record 7 of Set 12 | puerto escondido
# Processing Record 8 of Set 12 | nevesinje
# Processing Record 9 of Set 12 | sambava
# Processing Record 10 of Set 12 | hidalgo
# Processing Record 11 of Set 12 | san carlos
# Processing Record 12 of Set 12 | sanchez
# Processing Record 13 of Set 12 | balabac
# Processing Record 14 of Set 12 | palmas
# Processing Record 15 of Set 12 | sangar
# Processing Record 16 of Set 12 | svobodnyy
# Processing Record 17 of Set 12 | nyurba
# Processing Record 18 of Set 12 | karakol
# Processing Record 19 of Set 12 | ribeira brava
# Processing Record 20 of Set 12 | goderich
# Processing Record 21 of Set 12 | meadow lake
# Processing Record 22 of Set 12 | tonaya
# Processing Record 23 of Set 12 | touros
# Processing Record 24 of Set 12 | trincomalee
# Processing Record 25 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 12 | nokha
# Processing Record 27 of Set 12 | tsogni
# Processing Record 28 of Set 12 | nouakchott
# Processing Record 29 of Set 12 | jizan
# Processing Record 30 of Set 12 | lokosovo
# Processing Record 31 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 32 of Set 12 | kampene
# Processing Record 33 of Set 12 | hanna
# Processing Record 34 of Set 12 | ghanzi
# Processing Record 35 of Set 12 | fayaoue
# Processing Record 36 of Set 12 | vic
# Processing Record 37 of Set 12 | benghazi
# Processing Record 38 of Set 12 | xichang
# Processing Record 39 of Set 12 | serenje
# Processing Record 40 of Set 12 | tignere
# Processing Record 41 of Set 12 | thaba-tseka
# Processing Record 42 of Set 12 | pottsville
# Processing Record 43 of Set 12 | la rochelle
# Processing Record 44 of Set 12 | sorong
# Processing Record 45 of Set 12 | segezha
# Processing Record 46 of Set 12 | nelson bay
# Processing Record 47 of Set 12 | gizo
# Processing Record 48 of Set 12 | springdale
# Processing Record 49 of Set 12 | kota kinabalu
# Processing Record 50 of Set 12 | xingcheng
# Processing Record 1 of Set 13 | coxim
# Processing Record 2 of Set 13 | saint anthony
# Processing Record 3 of Set 13 | tura
# Processing Record 4 of Set 13 | manzhouli
# Processing Record 5 of Set 13 | assiniboia
# Processing Record 6 of Set 13 | mogadishu
# Processing Record 7 of Set 13 | olinda
# Processing Record 8 of Set 13 | atar
# Processing Record 9 of Set 13 | plettenberg bay
# Processing Record 10 of Set 13 | sayyan
# Processing Record 11 of Set 13 | tiassale
# Processing Record 12 of Set 13 | xiongshi
# City not found. Skipping...
# Processing Record 13 of Set 13 | florianopolis
# Processing Record 14 of Set 13 | yashalta
# Processing Record 15 of Set 13 | aiken
# Processing Record 16 of Set 13 | galveston
# Processing Record 17 of Set 13 | nampula
# Processing Record 18 of Set 13 | kodinsk
# Processing Record 19 of Set 13 | alta floresta
# Processing Record 20 of Set 13 | santa rosa
# Processing Record 21 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 13 | broome
# Processing Record 23 of Set 13 | morehead
# Processing Record 24 of Set 13 | nizwa
# Processing Record 25 of Set 13 | sobolevo
# Processing Record 26 of Set 13 | kurri kurri
# Processing Record 27 of Set 13 | mitu
# Processing Record 28 of Set 13 | maracacume
# Processing Record 29 of Set 13 | hamilton
# Processing Record 30 of Set 13 | shatrovo
# Processing Record 31 of Set 13 | plymouth
# Processing Record 32 of Set 13 | watsa
# Processing Record 33 of Set 13 | erzin
# Processing Record 34 of Set 13 | vestmannaeyjar
# Processing Record 35 of Set 13 | ketchikan
# Processing Record 36 of Set 13 | gander
# Processing Record 37 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 13 | soderhamn
# Processing Record 40 of Set 13 | mareeba
# Processing Record 41 of Set 13 | george
# Processing Record 42 of Set 13 | puerto narino
# Processing Record 43 of Set 13 | srednekolymsk
# Processing Record 44 of Set 13 | korla
# Processing Record 45 of Set 13 | salinopolis
# Processing Record 46 of Set 13 | almaznyy
# Processing Record 47 of Set 13 | funadhoo
# Processing Record 48 of Set 13 | mora
# Processing Record 49 of Set 13 | bosaso
# Processing Record 50 of Set 13 | armidale
# Processing Record 1 of Set 14 | algiers
# Processing Record 2 of Set 14 | phun phin
# City not found. Skipping...
# Processing Record 3 of Set 14 | taunusstein
# Processing Record 4 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 5 of Set 14 | ippy
# Processing Record 6 of Set 14 | vernon
# Processing Record 7 of Set 14 | okhotsk
# Processing Record 8 of Set 14 | kiunga
# Processing Record 9 of Set 14 | mayo
# Processing Record 10 of Set 14 | puerto madero
# Processing Record 11 of Set 14 | kupang
# Processing Record 12 of Set 14 | mizan teferi
# Processing Record 13 of Set 14 | lichinga
# Processing Record 14 of Set 14 | ambunti
# Processing Record 15 of Set 14 | galeana
# Processing Record 16 of Set 14 | birjand
# Processing Record 17 of Set 14 | lafia
# Processing Record 18 of Set 14 | deputatskiy
# Processing Record 19 of Set 14 | moultrie
# Processing Record 20 of Set 14 | pacific grove
# Processing Record 21 of Set 14 | manchester
# Processing Record 22 of Set 14 | shenjiamen
# Processing Record 23 of Set 14 | candawaga
# City not found. Skipping...
# Processing Record 24 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 25 of Set 14 | ossora
# Processing Record 26 of Set 14 | havre-saint-pierre
# Processing Record 27 of Set 14 | sesimbra
# Processing Record 28 of Set 14 | bilma
# Processing Record 29 of Set 14 | port hardy
# Processing Record 30 of Set 14 | beringovskiy
# Processing Record 31 of Set 14 | methven
# Processing Record 32 of Set 14 | colonial heights
# Processing Record 33 of Set 14 | karasjok
# Processing Record 34 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 14 | nishihara
# Processing Record 36 of Set 14 | horodnytsya
# Processing Record 37 of Set 14 | novoagansk
# Processing Record 38 of Set 14 | rocha
# Processing Record 39 of Set 14 | igarka
# Processing Record 40 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 41 of Set 14 | richards bay
# Processing Record 42 of Set 14 | adrar
# Processing Record 43 of Set 14 | siparia
# Processing Record 44 of Set 14 | vila franca do campo
# Processing Record 45 of Set 14 | stepnyak
# Processing Record 46 of Set 14 | itarema
# Processing Record 47 of Set 14 | marawi
# Processing Record 48 of Set 14 | hualmay
# Processing Record 49 of Set 14 | pregradnoye
# Processing Record 50 of Set 14 | buala
# Processing Record 1 of Set 15 | viedma
# Processing Record 2 of Set 15 | santa cruz del norte
# Processing Record 3 of Set 15 | domokos
# Processing Record 4 of Set 15 | outlook
# Processing Record 5 of Set 15 | saint-pierre
# Processing Record 6 of Set 15 | vostok
# Processing Record 7 of Set 15 | karla
# Processing Record 8 of Set 15 | langfang
# Processing Record 9 of Set 15 | santa marta
# Processing Record 10 of Set 15 | hajiganj
# Processing Record 11 of Set 15 | takoradi
# Processing Record 12 of Set 15 | otradnoye
# Processing Record 13 of Set 15 | bulaevo
# Processing Record 14 of Set 15 | fort nelson
# Processing Record 15 of Set 15 | sembabule
# Processing Record 16 of Set 15 | pio xii
# Processing Record 17 of Set 15 | maragogi
# Processing Record 18 of Set 15 | jiexiu
# Processing Record 19 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 15 | natal
# Processing Record 21 of Set 15 | kavaratti
# Processing Record 22 of Set 15 | joensuu
# Processing Record 23 of Set 15 | luba
# Processing Record 24 of Set 15 | shwebo
# Processing Record 25 of Set 15 | verkhne-katunskoye
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ambon      ID  -3.6954  128.1814     78.94        89          20
# 1  Komsomolskiy      UZ  40.4272   71.7189     44.02        69          15
# 2    Bredasdorp      ZA -34.5322   20.0403     59.29        80          82
# 3  Puerto Ayora      EC  -0.7393  -90.3518     70.56        87          60
# 4       Rikitea      PF -23.1203 -134.9692     74.80        80          98
# 5  Cheremukhovo      RU  60.3484   59.9851     28.36        64         100
# 6    Georgetown      MY   5.4112  100.3354     78.89        86          20
# 7       Ushuaia      AR -54.8000  -68.3000     46.06        61          75
# 8         Bowen      AU -20.0167  148.2333     77.50        57           9
# 9  Punta Arenas      CL -53.1500  -70.9167     48.31        46          20
#
#    Wind Speed      Current Description
# 0        4.61               few clouds
# 1        1.30               few clouds
# 2        2.91            broken clouds
# 3        5.01            broken clouds
# 4       18.25          overcast clouds
# 5        3.78          overcast clouds
# 6        3.44               few clouds
# 7       25.32  light intensity drizzle
# 8        8.88                clear sky
# 9       33.38               few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
